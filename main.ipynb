# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_error

# %%
df = pd.read_csv('data.csv')
df.head()
df.describe()
# Out:
#              Age        Salary
# count  16.000000     16.000000
# mean   40.625000  54238.329585
# std    11.206397  14263.246310
# min    19.000000  25281.000000
# 25%    35.000000  44818.975000
# 50%    40.000000  57313.923000
# 75%    47.000000  65090.250000
# max    60.000000  71336.000000

# %%
sns.scatterplot(x='Age', y='Salary', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x = df.drop('Salary', axis=1)
y = df['Salary']
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(train_x, train_y)
y_pred = model.predict(test_x.values)
print(mean_absolute_error(test_y, y_pred))
print(df["Salary"].mean())
# Out:
# 6606.66781445286
# 54238.32958516874
# C:\Users\roman\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
sns.scatterplot(x='Age', y='Salary', data=df)
plt.plot(test_x, y_pred)

# %%
model.predict([[51]])
# Out:
# C:\Users\roman\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([66710.12060674])

# %%
sns.regplot(x='Age', y='Salary', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>
